# %% [markdown]
# <a href="https://colab.research.google.com/github/arindam44/Assignment-3/blob/arindam44/pandas-3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
wine_df=pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data')
wine_df.head(5)
# Out:
#    1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29  5.64  1.04  3.92  \
# 0  1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28  4.38  1.05  3.40
# 1  1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81  5.68  1.03  3.17
# 2  1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18  7.80  0.86  3.45
# 3  1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82  4.32  1.04  2.93
# 4  1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97  6.75  1.05  2.85
#
#    1065
# 0  1050
# 1  1185
# 2  1480
# 3   735
# 4  1450

# %%
wine_df_copy = wine_df
nrow = wine_df_copy.shape[0]
for i in range(1,nrow):
  if i%2 != 0:
    wine_df_copy = wine_df_copy.drop(i)
    
wine_df_copy.head(10)
# Out:
#     1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29  5.64  1.04  3.92  \
# 0   1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28  4.38  1.05  3.40
# 2   1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18  7.80  0.86  3.45
# 4   1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97  6.75  1.05  2.85
# 6   1  14.06  2.15  2.61  17.6  121  2.60  2.51  0.31  1.25  5.05  1.06  3.58
# 8   1  13.86  1.35  2.27  16.0   98  2.98  3.15  0.22  1.85  7.22  1.01  3.55
# 10  1  14.12  1.48  2.32  16.8   95  2.20  2.43  0.26  1.57  5.00  1.17  2.82
# 12  1  14.75  1.73  2.39  11.4   91  3.10  3.69  0.43  2.81  5.40  1.25  2.73
# 14  1  13.63  1.81  2.70  17.2  112  2.85  2.91  0.30  1.46  7.30  1.28  2.88
# 16  1  13.83  1.57  2.62  20.0  115  2.95  3.40  0.40  1.72  6.60  1.13  2.57
# 18  1  13.64  3.10  2.56  15.2  116  2.70  3.03  0.17  1.66  5.10  0.96  3.36
#
#     1065
# 0   1050
# 2   1480
# 4   1450
# 6   1295
# 8   1045
# 10  1280
# 12  1150
# 14  1310
# 16  1130
# ...

# %%
wine_df.columns = ['Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids','Nonflavanoid phenols','Proanthocyanins','Color intensity','Hue','OD280/OD315 of diluted wines','Proline','']
wine_df.head(5)
# Out:
#    Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 0        1       13.20  1.78               2.14       11.2            100
# 1        1       13.16  2.36               2.67       18.6            101
# 2        1       14.37  1.95               2.50       16.8            113
# 3        1       13.24  2.59               2.87       21.0            118
# 4        1       14.20  1.76               2.45       15.2            112
#
#    Flavanoids  Nonflavanoid phenols  Proanthocyanins  Color intensity   Hue  \
# 0        2.65                  2.76             0.26             1.28  4.38
# 1        2.80                  3.24             0.30             2.81  5.68
# 2        3.85                  3.49             0.24             2.18  7.80
# 3        2.80                  2.69             0.39             1.82  4.32
# 4        3.27                  3.39             0.34             1.97  6.75
#
#    OD280/OD315 of diluted wines  Proline
# ...

# %%
wine_df.loc[[0,1,2],['Alcohol']] = np.nan
wine_df.head(5)
# Out:
#    Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 0      NaN       13.20  1.78               2.14       11.2            100
# 1      NaN       13.16  2.36               2.67       18.6            101
# 2      NaN       14.37  1.95               2.50       16.8            113
# 3      1.0       13.24  2.59               2.87       21.0            118
# 4      1.0       14.20  1.76               2.45       15.2            112
#
#    Flavanoids  Nonflavanoid phenols  Proanthocyanins  Color intensity   Hue  \
# 0        2.65                  2.76             0.26             1.28  4.38
# 1        2.80                  3.24             0.30             2.81  5.68
# 2        3.85                  3.49             0.24             2.18  7.80
# 3        2.80                  2.69             0.39             1.82  4.32
# 4        3.27                  3.39             0.34             1.97  6.75
#
#    OD280/OD315 of diluted wines  Proline
# ...

# %%
random = np.random.randint(0,10,10)
print(random)
# Out:
# [3 8 8 4 9 1 2 5 6 4]

# %%
wine_df.loc[random,['Alcohol']] = np.nan
wine_df.head(10)
# Out:
#    Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 0      NaN       13.20  1.78               2.14       11.2            100
# 1      NaN       13.16  2.36               2.67       18.6            101
# 2      NaN       14.37  1.95               2.50       16.8            113
# 3      NaN       13.24  2.59               2.87       21.0            118
# 4      NaN       14.20  1.76               2.45       15.2            112
# 5      NaN       14.39  1.87               2.45       14.6             96
# 6      NaN       14.06  2.15               2.61       17.6            121
# 7      1.0       14.83  1.64               2.17       14.0             97
# 8      NaN       13.86  1.35               2.27       16.0             98
# 9      NaN       14.10  2.16               2.30       18.0            105
#
#    Flavanoids  Nonflavanoid phenols  Proanthocyanins  Color intensity   Hue  \
# 0        2.65                  2.76             0.26             1.28  4.38
# ...

# %%
pd.isnull(wine_df['Alcohol']).sum()
# Out:
# 9

# %%
null = pd.notnull(wine_df['Alcohol'])
wine_df = wine_df[null]
wine_df.head(10)
# Out:
#     Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 7       1.0       14.83  1.64               2.17       14.0             97
# 10      1.0       14.12  1.48               2.32       16.8             95
# 11      1.0       13.75  1.73               2.41       16.0             89
# 12      1.0       14.75  1.73               2.39       11.4             91
# 13      1.0       14.38  1.87               2.38       12.0            102
# 14      1.0       13.63  1.81               2.70       17.2            112
# 15      1.0       14.30  1.92               2.72       20.0            120
# 16      1.0       13.83  1.57               2.62       20.0            115
# 17      1.0       14.19  1.59               2.48       16.5            108
# 18      1.0       13.64  3.10               2.56       15.2            116
#
#     Flavanoids  Nonflavanoid phenols  Proanthocyanins  Color intensity  Hue  \
# ...
