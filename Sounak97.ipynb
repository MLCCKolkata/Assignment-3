# %%
import numpy as np
import pandas as pd

# %%
iris_df = pd.read_csv('https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv')

# %%
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
print(iris_df.shape)#no. of rows and columns
print(iris_df.shape[0])
print(iris_df.shape[1])
# Out:
# (150, 5)
# 150
# 5

# %% [markdown]
# Printing all columns

# %%
print(iris_df.columns)
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %% [markdown]
# SHUFFLING

# %%
print(iris_df.head())
new=np.random.permutation(iris_df.index)
iris_df=iris_df.reindex(index=new)
print(iris_df.head())#gives different results everytime it is executed
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 1            4.9         30.0           1.4          0.2      setosa
# 92           5.8         26.0           4.0          1.2  versicolor
# 17           5.1         35.0           1.4          0.3      setosa
# 84           5.4         30.0           4.5          1.5  versicolor
# 44           5.1         38.0           1.9          0.4      setosa
#      sepal_length  sepal_width  petal_length  petal_width     species
# 5             5.4         39.0           1.7          0.4      setosa
# 140           6.7         31.0           5.6          2.4   virginica
# 70            5.9         32.0           4.8          1.8  versicolor
# 36            5.5         35.0           1.3          0.2      setosa
# 90            5.5         26.0           4.4          1.2  versicolor

# %% [markdown]
# Applying operations

# %%
print(iris_df.head())
iris_df['sepal_width']*=10
print(iris_df.head())
iris_df['sepal_width']/=10
print(iris_df.head())
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 5             5.4         39.0           1.7          0.4      setosa
# 140           6.7         31.0           5.6          2.4   virginica
# 70            5.9         32.0           4.8          1.8  versicolor
# 36            5.5         35.0           1.3          0.2      setosa
# 90            5.5         26.0           4.4          1.2  versicolor
#      sepal_length  sepal_width  petal_length  petal_width     species
# 5             5.4        390.0           1.7          0.4      setosa
# 140           6.7        310.0           5.6          2.4   virginica
# 70            5.9        320.0           4.8          1.8  versicolor
# 36            5.5        350.0           1.3          0.2      setosa
# 90            5.5        260.0           4.4          1.2  versicolor
#      sepal_length  sepal_width  petal_length  petal_width     species
# ...

# %%
iris_df[iris_df['sepal_width']>33]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 5             5.4         39.0           1.7          0.4      setosa
# 36            5.5         35.0           1.3          0.2      setosa
# 4             5.0         36.0           1.4          0.2      setosa
# 16            5.4         39.0           1.3          0.4      setosa
# 21            5.1         37.0           1.5          0.4      setosa
# 31            5.4         34.0           1.5          0.4      setosa
# 7             5.0         34.0           1.5          0.2      setosa
# 28            5.2         34.0           1.4          0.2      setosa
# 44            5.1         38.0           1.9          0.4      setosa
# 32            5.2         41.0           1.5          0.1      setosa
# 27            5.2         35.0           1.5          0.2      setosa
# 14            5.8         40.0           1.2          0.2      setosa
# ...

# %%
iris_df[(iris_df['sepal_width']>33) & (iris_df['species'] == 'versicolor')]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 85           6.0         34.0           4.5          1.6  versicolor

# %% [markdown]
# Sorting a column by value

# %%
iris_df.sort_values(by='sepal_width')
iris_df.sort_values(by='sepal_width',ascending=False)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 15            5.7         44.0           1.5          0.4      setosa
# 33            5.5         42.0           1.4          0.2      setosa
# 32            5.2         41.0           1.5          0.1      setosa
# 14            5.8         40.0           1.2          0.2      setosa
# 16            5.4         39.0           1.3          0.4      setosa
# 5             5.4         39.0           1.7          0.4      setosa
# 44            5.1         38.0           1.9          0.4      setosa
# 18            5.7         38.0           1.7          0.3      setosa
# 46            5.1         38.0           1.6          0.2      setosa
# 19            5.1         38.0           1.5          0.3      setosa
# 117           7.7         38.0           6.7          2.2   virginica
# 131           7.9         38.0           6.4          2.0   virginica
# ...

# %% [markdown]
# Unique Species

# %%
species = iris_df['species'].unique()

print(species)
# Out:
# ['setosa' 'virginica' 'versicolor']

# %% [markdown]
# Selecting species by Boolean /mask

# %%
setosa = iris_df[iris_df['species'] == species[0]]

setosa.head()
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 5            5.4         39.0           1.7          0.4  setosa
# 36           5.5         35.0           1.3          0.2  setosa
# 4            5.0         36.0           1.4          0.2  setosa
# 16           5.4         39.0           1.3          0.4  setosa
# 21           5.1         37.0           1.5          0.4  setosa

# %%
virginica = iris_df[iris_df['species'] == species[1]]

virginica.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 140           6.7         31.0           5.6          2.4  virginica
# 100           6.3         33.0           6.0          2.5  virginica
# 111           6.4         27.0           5.3          1.9  virginica
# 106           4.9         25.0           4.5          1.7  virginica
# 116           6.5         30.0           5.5          1.8  virginica

# %%
versicolor = iris_df[iris_df['species'] == species[2]]

versicolor.head()
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 70           5.9         32.0           4.8          1.8  versicolor
# 90           5.5         26.0           4.4          1.2  versicolor
# 57           4.9         24.0           3.3          1.0  versicolor
# 99           5.7         28.0           4.1          1.3  versicolor
# 82           5.8         27.0           3.9          1.2  versicolor

# %% [markdown]
# Describe

# %%
setosa.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000     50.00000
# mean        5.00600    34.180000      1.464000      0.24400
# std         0.35249     3.810244      0.173511      0.10721
# min         4.30000    23.000000      1.000000      0.10000
# 25%         4.80000    31.250000      1.400000      0.20000
# 50%         5.00000    34.000000      1.500000      0.20000
# 75%         5.20000    36.750000      1.575000      0.30000
# max         5.80000    44.000000      1.900000      0.60000

# %%
virginica.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000     50.00000
# mean        6.58800    29.740000      5.552000      2.02600
# std         0.63588     3.224966      0.551895      0.27465
# min         4.90000    22.000000      4.500000      1.40000
# 25%         6.22500    28.000000      5.100000      1.80000
# 50%         6.50000    30.000000      5.550000      2.00000
# 75%         6.90000    31.750000      5.875000      2.30000
# max         7.90000    38.000000      6.900000      2.50000

# %%
versicolor.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count     50.000000    50.000000     50.000000    50.000000
# mean       5.936000    27.700000      4.260000     1.326000
# std        0.516171     3.137983      0.469911     0.197753
# min        4.900000    20.000000      3.000000     1.000000
# 25%        5.600000    25.250000      4.000000     1.200000
# 50%        5.900000    28.000000      4.350000     1.300000
# 75%        6.300000    30.000000      4.600000     1.500000
# max        7.000000    34.000000      5.100000     1.800000

# %% [markdown]
# Plotting

# %%
import matplotlib.pyplot as plot
plot.hist(setosa['sepal_length'])
plot.hist(versicolor['sepal_length'])
plot.hist(virginica['sepal_length'])
# Out:
# (array([ 1.,  0.,  5.,  5.,  8.,  9., 10.,  5.,  1.,  6.]),
#  array([4.9, 5.2, 5.5, 5.8, 6.1, 6.4, 6.7, 7. , 7.3, 7.6, 7.9]),
#  <a list of 10 Patch objects>)
