# %%
import numpy as np
import pandas as pd

# %%
wine_df=pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data")

# %%
wine_df.head()
# Out:
#    1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29  5.64  1.04  3.92  \
# 0  1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28  4.38  1.05  3.40
# 1  1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81  5.68  1.03  3.17
# 2  1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18  7.80  0.86  3.45
# 3  1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82  4.32  1.04  2.93
# 4  1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97  6.75  1.05  2.85
#
#    1065
# 0  1050
# 1  1185
# 2  1480
# 3   735
# 4  1450

# %%
wine_df_copy=wine_df
print(wine_df_copy)
# Out:
#      1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29       5.64  1.04  \
# 0    1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28   4.380000  1.05
# 1    1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81   5.680000  1.03
# 2    1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18   7.800000  0.86
# 3    1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82   4.320000  1.04
# 4    1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97   6.750000  1.05
# 5    1  14.39  1.87  2.45  14.6   96  2.50  2.52  0.30  1.98   5.250000  1.02
# 6    1  14.06  2.15  2.61  17.6  121  2.60  2.51  0.31  1.25   5.050000  1.06
# 7    1  14.83  1.64  2.17  14.0   97  2.80  2.98  0.29  1.98   5.200000  1.08
# 8    1  13.86  1.35  2.27  16.0   98  2.98  3.15  0.22  1.85   7.220000  1.01
# 9    1  14.10  2.16  2.30  18.0  105  2.95  3.32  0.22  2.38   5.750000  1.25
# 10   1  14.12  1.48  2.32  16.8   95  2.20  2.43  0.26  1.57   5.000000  1.17
# ...

# %%
wine_df_copy=wine_df_copy[::2]

# %%
print(wine_df_copy)
# Out:
#      1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29   5.64  1.04  \
# 0    1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28   4.38  1.05
# 4    1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97   6.75  1.05
# 8    1  13.86  1.35  2.27  16.0   98  2.98  3.15  0.22  1.85   7.22  1.01
# 12   1  14.75  1.73  2.39  11.4   91  3.10  3.69  0.43  2.81   5.40  1.25
# 16   1  13.83  1.57  2.62  20.0  115  2.95  3.40  0.40  1.72   6.60  1.13
# 20   1  12.93  3.80  2.65  18.6  102  2.41  2.41  0.25  1.98   4.50  1.03
# 24   1  13.05  2.05  3.22  25.0  124  2.63  2.68  0.47  1.92   3.58  1.13
# 28   1  14.02  1.68  2.21  16.0   96  2.65  2.33  0.26  1.98   4.70  1.04
# 32   1  13.76  1.53  2.70  19.5  132  2.95  2.74  0.50  1.35   5.40  1.25
# 36   1  13.05  1.65  2.55  18.0   98  2.45  2.43  0.29  1.44   4.25  1.12
# 40   1  13.41  3.84  2.12  18.8   90  2.45  2.68  0.27  1.48   4.28  0.91
# 44   1  14.21  4.04  2.44  18.9  111  2.85  2.65  0.30  1.25   5.24  0.87
# ...

# %%
wine_df_copy.rename(columns={1:'Alcohol',14.23:'Malic Acid',1.71:'Ash',2.43:'Alcalinity of ash',15.6:'Magnesium',127:'Total phenols',2.8:'Flavanoids',3.06:'Nonflavanoids phenols',.28:'Proanthocyanins',2.29:'Color intenstiy',5.64:'Hue',1.04:'OD280/OD315 of diluted wines',3.92:'Proline'},inplace=True)
#Renaming columns

# %%
print(wine_df_copy)
# Out:
#      1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29   5.64  1.04  \
# 0    1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28   4.38  1.05
# 4    1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97   6.75  1.05
# 8    1  13.86  1.35  2.27  16.0   98  2.98  3.15  0.22  1.85   7.22  1.01
# 12   1  14.75  1.73  2.39  11.4   91  3.10  3.69  0.43  2.81   5.40  1.25
# 16   1  13.83  1.57  2.62  20.0  115  2.95  3.40  0.40  1.72   6.60  1.13
# 20   1  12.93  3.80  2.65  18.6  102  2.41  2.41  0.25  1.98   4.50  1.03
# 24   1  13.05  2.05  3.22  25.0  124  2.63  2.68  0.47  1.92   3.58  1.13
# 28   1  14.02  1.68  2.21  16.0   96  2.65  2.33  0.26  1.98   4.70  1.04
# 32   1  13.76  1.53  2.70  19.5  132  2.95  2.74  0.50  1.35   5.40  1.25
# 36   1  13.05  1.65  2.55  18.0   98  2.45  2.43  0.29  1.44   4.25  1.12
# 40   1  13.41  3.84  2.12  18.8   90  2.45  2.68  0.27  1.48   4.28  0.91
# 44   1  14.21  4.04  2.44  18.9  111  2.85  2.65  0.30  1.25   5.24  0.87
# ...

# %%
wine_df_copy.head()
# Out:
#     1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29  5.64  1.04  3.92  \
# 0   1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28  4.38  1.05  3.40
# 4   1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97  6.75  1.05  2.85
# 8   1  13.86  1.35  2.27  16.0   98  2.98  3.15  0.22  1.85  7.22  1.01  3.55
# 12  1  14.75  1.73  2.39  11.4   91  3.10  3.69  0.43  2.81  5.40  1.25  2.73
# 16  1  13.83  1.57  2.62  20.0  115  2.95  3.40  0.40  1.72  6.60  1.13  2.57
#
#     1065
# 0   1050
# 4   1450
# 8   1045
# 12  1150
# 16  1130

# %% [markdown]
# Create an array of 10 random numbers uptill 10 and assign it to a variable named random

# %%
import random 
i=0
r=[]
for i in range(10):
  a=random.uniform(float(1),float(10))
  r.append(a)
  i+=1
print(r)
# Out:
# [1.0355307122667285, 2.876907827121046, 8.449537712749636, 9.986961903306137, 1.557510551343713, 1.302624967986766, 1.1265007673179914, 6.788163856067978, 4.956732917260711, 2.3207323299399345]
